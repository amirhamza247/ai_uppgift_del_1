# %% [markdown]
# # Kapitel 1 - Introduktion till maskininlärning

# %% [markdown]
# ## Faktafrågor

# %% [markdown]
# 1. AI är den stora begreppet som täcker både ML och DL medans ML är under AL men över DL och DL är den innersta under ML.

# %% [markdown]
# 2. Klassificering, klusstring, regression, dimentionering,

# %% [markdown]
# 3. a. Syftet med att dela data är för att vi vill ha en test data som är orörd som vi kan testa vår modell på. Vi delar upp i trainfull och test och sedan delar vi trainfull ytterligare i train och val för att träna data på train och predikta val och när vi har hittat den bästa modellen då tränar vi modellen trainfull datan och gör predektion på test datan.
#
# b. k-delad korsvalidering är när man tar datan och delar upp i mindre grupper och man tränar validerar modellen på hela datan. tx om man delar hela datan i 4 grupper då är grupp 1,2,3,4 train och 5 blir val och sedan 1,2,3,5 blir train och 4 blir val, sedan 1,2,4,5 blir train och 3 blir val osv tills all grupper har både blivit tränad på och validrad på.
#
# c. RMSE är ett sätt att se det genom snitlliga felet på en modell. desto lägre siffar är ju bättre.
#
# d. Hyperparameter är inställningar som vi sätter utanför modellen innan den körs mendans parameter är inställningar som modellen själv bestämmer när den kör.
#
# e. Grid search innebär att modellen ska testa alla inställningar och hitta den bästa när den har hittat den bästa inställningen ska den då träna modellen igen på den bästa inställningen enligt refit = True.
#
# f. Kategorisk data är data som är inte kontonuerlig. exempel på kategorisk data är nominal data som inte har natrulig övergång utan det är fasta klasser tx. hus, sko, sömn. Ordinal data är ett annat exempel fast här har datan en naturlig övergång från ena till den andra tx. barn, tonåring, vuxen man ska sätta 1,2,3. one-hot-encoding är när man har en rubrik för varje feature. ordinal encoding är när man kan byta ut features mot siffror. dummy-variable-encoding är när man kan byta ut features mot siffror men droppar en feature for att undgå multikollinearitets-problem.
#
# g. Feature engineering betyder när man slår ihop olika columner eller droppar visa kolumner för att effektivisera och förenkla datan för modellen.
#
# h. Principle of parsimony betyder att man gör saker så enklet så länge det går.

# %% [markdown]
# 4. det betyder att en modell försöker lika det vi gör i verkligheten men en modell brukar alltid skippa visa dealjer, den kan helt enklet inte fånga var enda detalj av verkligheten. alltså därför är den en förenkling av verkligheten.

# %% [markdown]
# 5. överanpassad betyder att man har försökt träna modellen för mycket vilket leder till att den lär sig brus i datan istället för att lära sig den generlla mönstret.

# %% [markdown]
# 6. i scikit-learns design principer så är högre siffror en indikation av bättre prestenda och hela scikit-learn är byggd kring detta.

# %% [markdown]
# 7. tvärsnittsdata är data för flera variabler under en tidpunkt. tidsseriedata är data samlad för en variabel under flera tidpunkter. paneldata är data för flera variabler under flera tidpunkter.
# exemple på tväsnittsdata kan vara, hus priser i stockholm på en måndag.
# exemple på tidseridata kan vara, guld pris aktie under 5 års tid.
# exemple på paneldata kan vara,samma 20 mat priser i alla svenksa städer, noterade varje dag i ett års tid.

# %% [markdown]
# ## Resonemangfrågor

# %% [markdown]
# 8. ML anävnds i flera olika områden till exemple inom kreditvärdighet, skräppostfilter, curn-prediktion och områden där DL används är bland annat självkörande bilar, chatgpt, alphafold, bildgenerering osv.

# %% [markdown]
# 9. vi anväder negetiv MSE för att vi vill hjälpa systemet att tolka mse resultaten enligt scikit-learn scoring. eftersom för mse är det minst som är bäst och i scikit-learn störst så när vi sätter minus tecken fram för mse värdet då följer den scikit-learn scoring.

# %% [markdown]
# ## Koduppgifter

# %% [markdown]
# uppgift_11:
# vi får 60-20-20 proportioner för att om vi säger hela datan är 100 punkter.
#
# 0.2 * 100 = 20 punkter      första test size
#
# nu har vi 80 punkter kvar av 100, här kommer vi dela ytterligare i train och test.
#
# 0.25 * 80 = 20 punkter     andra test size
#
# nu är det bara 60 punkter kvar av 100. Det är så vi får 60-20-20
